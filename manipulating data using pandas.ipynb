# %%
import pandas as pd
car_sales= pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]= car_sales["Make"].str.capitalize()

# %% [raw]
# car_sales

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     Bmw  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     Bmw  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %%
#column from series
seats_column=pd.Series([5,5,5,5,5])

#new column called seats
car_sales["Seats"]=seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     Bmw  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["Seats"]=car_sales["Seats"].fillna (car_sales["Seats"]).mean()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     Bmw  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
#or
car_sales["Seats"].fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     Bmw  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
car_liter=[1.0,2.0,1.0,2.0,1.0,2.0,1.0,2.0,1.0,2.0]

# %%
car_sales["Liter"]=car_liter
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0
# 4  Nissan  White         213095      4   $3,500.00    5.0    1.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0    1.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0    2.0
# 8  Toyota  White          60000      4   $6,250.00    5.0    1.0
# 9  Nissan  White          31600      4   $9,700.00    5.0    2.0

# %%
car_transmission=pd.Series(["Automatic","manual","Automatic","Manual"])
car_sales["Transmission"]= car_transmission

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0    Automatic
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0       manual
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0    Automatic
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0       Manual
# 4  Nissan  White         213095      4   $3,500.00    5.0    1.0          NaN
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0          NaN
# 6   Honda   Blue          45698      4   $7,500.00    5.0    1.0          NaN
# 7   Honda   Blue          54738      4   $7,000.00    5.0    2.0          NaN
# 8  Toyota  White          60000      4   $6,250.00    5.0    1.0          NaN
# 9  Nissan  White          31600      4   $9,700.00    5.0    2.0          NaN

# %%
car_sales["Transmission"].fillna("Manual", inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0    Automatic
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0       manual
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0    Automatic
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0       Manual
# 4  Nissan  White         213095      4   $3,500.00    5.0    1.0       Manual
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0       Manual
# 6   Honda   Blue          45698      4   $7,500.00    5.0    1.0       Manual
# 7   Honda   Blue          54738      4   $7,000.00    5.0    2.0       Manual
# 8  Toyota  White          60000      4   $6,250.00    5.0    1.0       Manual
# 9  Nissan  White          31600      4   $9,700.00    5.0    2.0       Manual

# %%
 car_sales["Total fuel used (L)"] =car_sales["Odometer (KM)"]/100 * car_sales["Liter"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission  \
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0    Automatic
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0       manual
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0    Automatic
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0       Manual
# 4  Nissan  White         213095      4   $3,500.00    5.0    1.0       Manual
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0       Manual
# 6   Honda   Blue          45698      4   $7,500.00    5.0    1.0       Manual
# 7   Honda   Blue          54738      4   $7,000.00    5.0    2.0       Manual
# 8  Toyota  White          60000      4   $6,250.00    5.0    1.0       Manual
# 9  Nissan  White          31600      4   $9,700.00    5.0    2.0       Manual
#
#    Total fuel used (L)
# 0              1500.43
# 1              1757.98
# 2               325.49
# ...

# %%
car_sales["Total fuel used (L)"]. plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#create a column from a single value
car_sales["Number of wheels"]= 4 
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission  \
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0    Automatic
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0       manual
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0    Automatic
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0       Manual
# 4  Nissan  White         213095      4   $3,500.00    5.0    1.0       Manual
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0       Manual
# 6   Honda   Blue          45698      4   $7,500.00    5.0    1.0       Manual
# 7   Honda   Blue          54738      4   $7,000.00    5.0    2.0       Manual
# 8  Toyota  White          60000      4   $6,250.00    5.0    1.0       Manual
# 9  Nissan  White          31600      4   $9,700.00    5.0    2.0       Manual
#
#    Total fuel used (L)  Number of wheels
# 0              1500.43                 4
# ...

# %%
car_sales["Number of wheels"]= 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission  \
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0    Automatic
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0       manual
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0    Automatic
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0       Manual
# 4  Nissan  White         213095      4   $3,500.00    5.0    1.0       Manual
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0       Manual
# 6   Honda   Blue          45698      4   $7,500.00    5.0    1.0       Manual
# 7   Honda   Blue          54738      4   $7,000.00    5.0    2.0       Manual
# 8  Toyota  White          60000      4   $6,250.00    5.0    1.0       Manual
# 9  Nissan  White          31600      4   $9,700.00    5.0    2.0       Manual
#
#    Total fuel used (L)  Number of wheels
# 0              1500.43                 4
# ...

# %%
car_sales["Passed Road safety"]=True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission  \
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0    Automatic
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0       manual
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0    Automatic
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0       Manual
# 4  Nissan  White         213095      4   $3,500.00    5.0    1.0       Manual
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0       Manual
# 6   Honda   Blue          45698      4   $7,500.00    5.0    1.0       Manual
# 7   Honda   Blue          54738      4   $7,000.00    5.0    2.0       Manual
# 8  Toyota  White          60000      4   $6,250.00    5.0    1.0       Manual
# 9  Nissan  White          31600      4   $9,700.00    5.0    2.0       Manual
#
#    Total fuel used (L)  Number of wheels  Passed Road safety
# ...

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission  \
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0    Automatic
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0       manual
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0       Manual
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0       Manual
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0    Automatic
#
#    Total fuel used (L)  Number of wheels  Passed Road safety
# 2               325.49                 4                True
# 1              1757.98                 4                True
# 3               223.58                 4                True
# 5              1984.26                 4                True
# 0              1500.43                 4                True

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission  \
# 6   Honda   Blue          45698      4   $7,500.00    5.0    1.0       Manual
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0       manual
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0       Manual
# 8  Toyota  White          60000      4   $6,250.00    5.0    1.0       Manual
# 9  Nissan  White          31600      4   $9,700.00    5.0    2.0       Manual
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0    Automatic
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0       Manual
# 7   Honda   Blue          54738      4   $7,000.00    5.0    2.0       Manual
# 4  Nissan  White         213095      4   $3,500.00    5.0    1.0       Manual
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0    Automatic
#
#    Total fuel used (L)  Number of wheels  Passed Road safety
# ...

# %%
car_sales_shuffled= car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission  \
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0    Automatic
# 7   Honda   Blue          54738      4   $7,000.00    5.0    2.0       Manual
# 9  Nissan  White          31600      4   $9,700.00    5.0    2.0       Manual
# 4  Nissan  White         213095      4   $3,500.00    5.0    1.0       Manual
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0       Manual
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0    Automatic
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0       manual
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0       Manual
# 8  Toyota  White          60000      4   $6,250.00    5.0    1.0       Manual
# 6   Honda   Blue          45698      4   $7,500.00    5.0    1.0       Manual
#
#    Total fuel used (L)  Number of wheels  Passed Road safety
# ...

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission  \
# 0  Toyota  White         150043      4   $4,000.00    5.0    1.0    Automatic
# 1   Honda    Red          87899      4   $5,000.00    5.0    2.0       manual
# 2  Toyota   Blue          32549      3   $7,000.00    5.0    1.0    Automatic
# 3     Bmw  Black          11179      5  $22,000.00    5.0    2.0       Manual
# 4  Nissan  White         213095      4   $3,500.00    5.0    1.0       Manual
# 5  Toyota  Green          99213      4   $4,500.00    5.0    2.0       Manual
# 6   Honda   Blue          45698      4   $7,500.00    5.0    1.0       Manual
# 7   Honda   Blue          54738      4   $7,000.00    5.0    2.0       Manual
# 8  Toyota  White          60000      4   $6,250.00    5.0    1.0       Manual
# 9  Nissan  White          31600      4   $9,700.00    5.0    2.0       Manual
#
#    Total fuel used (L)  Number of wheels  Passed Road safety
# ...

# %%
car_sales["Odometer (KM)"]= car_sales["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  Liter Transmission  \
# 0  Toyota  White      93776.875      4   $4,000.00    5.0    1.0    Automatic
# 1   Honda    Red      54936.875      4   $5,000.00    5.0    2.0       manual
# 2  Toyota   Blue      20343.125      3   $7,000.00    5.0    1.0    Automatic
# 3     Bmw  Black       6986.875      5  $22,000.00    5.0    2.0       Manual
# 4  Nissan  White     133184.375      4   $3,500.00    5.0    1.0       Manual
# 5  Toyota  Green      62008.125      4   $4,500.00    5.0    2.0       Manual
# 6   Honda   Blue      28561.250      4   $7,500.00    5.0    1.0       Manual
# 7   Honda   Blue      34211.250      4   $7,000.00    5.0    2.0       Manual
# 8  Toyota  White      37500.000      4   $6,250.00    5.0    1.0       Manual
# 9  Nissan  White      19750.000      4   $9,700.00    5.0    2.0       Manual
#
#    Total fuel used (L)  Number of wheels  Passed Road safety
# ...
